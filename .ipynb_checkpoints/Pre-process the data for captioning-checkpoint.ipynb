# %%
import pickle
import json

caption_file = './data/task_of_interest_raw_caption.json'
captions = json.load(open(caption_file,  'r'))

s3d_file = './data/s3d_feature_hub.pkl'
s3d_feat = pickle.load(open(s3d_file, 'rb'), encoding="utf-32")

def list_to_sent(sent_list):
    re = ''
    for sent in sent_list:
        re += sent + ' '
    return re

# %%
total_ann
# Out:
# {'q_XDwC6lyu0_0': {'time': [0.0, 23.125],
#   'cap': "lock up your house your valuables but just when you think you're safe think again yeah the bad guys are using something called bump keys to slip right past most locks i'd never heard of this before a lot of people have and many locksmiths we talked to you though didn't even want to tell us about them but the information is widely available on the internet and we thought we would ",
#   'feature': array([[5.86054812e-04, 2.63510767e-04, 1.00554171e-04, ...,
#           6.97470896e-05, 1.17098723e-04, 2.56437669e-03],
#          [2.63944094e-04, 2.15934022e-04, 3.99022902e-05, ...,
#           2.90688127e-04, 0.00000000e+00, 2.01212079e-03],
#          [1.37045135e-04, 2.42693432e-06, 3.15577381e-05, ...,
#           1.39207332e-04, 2.60463821e-05, 1.92868663e-03],
#          ...,
#          [5.33025479e-04, 3.91734473e-04, 1.16973846e-04, ...,
#           3.26815236e-04, 4.86458885e-05, 2.68877810e-03],
#          [2.87345843e-04, 2.49849021e-04, 3.50019072e-05, ...,
#           4.40082222e-04, 3.41883242e-05, 2.40856782e-03],
#          [1.79309674e-04, 1.48380015e-04, 5.84564950e-05, ...,
#           3.46191373e-04, 1.98121925e-05, 2.59383116e-03]], dtype=float32)},
#  'q_XDwC6lyu0_1': {'time': [21.145, 62.39],
#   'cap': "show you what's out there so you can protect yourself brandon fonda is on your side tonight with the story holy crap that's crazy that was way too easy tiffany just witnessed a break-in at her house she let us break in but the way we did it scares her over at justin's house same reaction holy crap that's crazy that's quick that's quick it's called a bump key and ",
#   'feature': array([[1.7930967e-04, 1.4838002e-04, 5.8456495e-05, ..., 3.4619137e-04,
#           1.9812192e-05, 2.5938312e-03],
#          [1.6689632e-04, 1.0334527e-05, 6.3503139e-05, ..., 2.2557208e-04,
#           7.0354779e-04, 2.9820832e-03],
#          [1.0973205e-04, 5.4782686e-05, 7.7891098e-05, ..., 3.7618901e-04,
#           1.8694639e-04, 2.7716684e-03],
#          ...,
#          [3.4737939e-05, 1.7338709e-04, 4.9225584e-04, ..., 3.0895221e-04,
#           2.6875528e-04, 3.0548642e-03],
#          [1.7976791e-04, 3.3358313e-04, 1.0691320e-04, ..., 3.5134691e-04,
#           3.6886823e-04, 2.4985550e-03],
#          [3.9501892e-06, 1.1872746e-04, 2.2932926e-04, ..., 4.8537663e-04,
#           1.8037644e-03, 2.5541459e-03]], dtype=float32)},
#  'q_XDwC6lyu0_2': {'time': [59.58, 89.89],
#   'cap': "they can be used to get into most dead bolts door locks and padlocks that dip yeah it's just scary it's scary to see him walk up to my door stick a little key in there and pop it open let me explain when a normal key is put in a lock little pins are pushed up allowing the key to turn opening the lock with a bump key a key with special grooves and a little bit of force the pins all pop ",
#   'feature': array([[3.9501892e-06, 1.1872746e-04, 2.2932926e-04, ..., 4.8537663e-04,
#           1.8037644e-03, 2.5541459e-03],
#          [1.8146047e-03, 1.2639716e-05, 4.5140617e-04, ..., 6.5285212e-04,
#           1.2967868e-03, 2.9516635e-03],
#          [3.6615887e-04, 8.4392021e-05, 2.7154537e-04, ..., 2.5248301e-04,
#           1.7091766e-04, 3.0500544e-03],
#          ...,
#          [6.5915496e-04, 1.3241947e-03, 1.1595631e-03, ..., 4.2167876e-04,
#           1.5506362e-04, 2.7268133e-03],
#          [3.6224010e-04, 1.4941157e-03, 8.0830057e-04, ..., 8.0250797e-04,
#           4.3317734e-04, 2.4508378e-03],
#          [5.7781342e-04, 2.7164069e-05, 7.0299522e-04, ..., 1.3529419e-04,
#           3.9927659e-04, 2.7257497e-03]], dtype=float32)},
#  'q_XDwC6lyu0_3': {'time': [86.905, 115.595],
#   'cap': "up for a split second allowing the key to unlock whatever you had locked up i hate to say this but locks are a defeatable piece of security you can ask any locksmith that you can have to ask a lot of criminals that they're not hard to get past the keys are surprisingly easy to get a hold of so i thought we'd give it a try with just a few clicks of the mouse we were able to get pack of ",
#   'feature': array([[5.7781342e-04, 2.7164069e-05, 7.0299522e-04, ..., 1.3529419e-04,
#           3.9927659e-04, 2.7257497e-03],
#          [1.9457673e-03, 3.9822119e-04, 7.4359472e-04, ..., 1.5248696e-03,
#           1.5403572e-04, 2.2161887e-03],
#          [4.8434202e-04, 1.4282124e-04, 2.1337782e-04, ..., 7.3343504e-04,
#           2.3297519e-04, 4.1078161e-03],
#          ...,
#          [1.2905247e-03, 5.6961355e-05, 7.1341771e-04, ..., 4.5695319e-04,
#           8.4257874e-05, 2.9445202e-03],
#          [1.7555793e-03, 1.1433585e-04, 1.0743209e-03, ..., 6.7091780e-04,
#           5.7127188e-05, 2.9658307e-03],
#          [1.3490352e-03, 5.4012871e-05, 6.3351041e-04, ..., 3.5096449e-04,
#           1.6836573e-04, 2.5944305e-03]], dtype=float32)},
#  'q_XDwC6lyu0_4': {'time': [113.175, 146.965],
#   'cap': "about 20 bump keys sent to us here it was alarmingly easy they arrived here in just a few short days it's it's out there the bumping and there are things you can do to prevent it and there's our things you can do to stop it dave owns a lock shop in nampa he's the guy you need to talk to to keep the bad guys out you don't have to spend a lot of money to protect yourself dave says ",
#   'feature': array([[1.3490352e-03, 5.4012871e-05, 6.3351041e-04, ..., 3.5096449e-04,
#           1.6836573e-04, 2.5944305e-03],
#          [5.4163614e-04, 0.0000000e+00, 3.7553121e-04, ..., 3.8868422e-04,
#           1.5210322e-04, 3.2425155e-03],
#          [7.5495115e-04, 3.9482929e-04, 4.2595272e-04, ..., 5.7052297e-04,
#           3.6630707e-04, 3.1516482e-03],
#          ...,
#          [1.9059877e-04, 5.0608400e-05, 2.4184865e-04, ..., 1.3284749e-04,
#           2.7233717e-04, 3.1603565e-03],
#          [1.4696835e-04, 6.0593487e-05, 4.9298798e-04, ..., 3.9329720e-04,
#           2.1728133e-04, 2.9388741e-03],
#          [5.7378074e-04, 0.0000000e+00, 3.2632443e-04, ..., 2.9432093e-04,
#           6.4468931e-04, 3.0920163e-03]], dtype=float32)},
#  'q_XDwC6lyu0_5': {'time': [143.71, 175.33],
#   'cap': 'you can go as inexpensive as a simple chain like the hotel things where you slide it over and you can push it i mean you could say just for a few bucks you can protect yourself or for a little more money and a lot more peace of mind you can buy locks that are bump resistant so we can do we can get them smart key this is smart key and this one is bum proof there are commercial style ',
#   'feature': array([[5.7378074e-04, 0.0000000e+00, 3.2632443e-04, ..., 2.9432093e-04,
#           6.4468931e-04, 3.0920163e-03],
#          [8.5357705e-04, 5.3784093e-05, 6.4657349e-04, ..., 7.8508700e-04,
#           1.7842176e-04, 3.0415836e-03],
#          [9.3384908e-04, 6.6786750e-05, 1.4897869e-03, ..., 5.2839739e-04,
#           1.2172535e-03, 2.5400682e-03],
#          ...,
#          [2.4415800e-04, 6.7078872e-05, 2.5326828e-04, ..., 3.4272971e-04,
#           2.8561385e-04, 3.1752551e-03],
#          [5.2953302e-04, 3.1939422e-04, 9.3981251e-04, ..., 1.5754446e-03,
#           0.0000000e+00, 3.0344066e-03],
#          [1.8593511e-03, 1.6055262e-04, 5.9855729e-04, ..., 2.0615007e-03,
#           5.7614097e-06, 3.3735831e-03]], dtype=float32)},
#  'q_XDwC6lyu0_6': {'time': [172.46, 202.85],
#   'cap': "keys that are bum proof now if you look at this it looks normal on this side but when you look on this side has the extra cuts on that side plus you have the cuts that are going to be on the top so what we call those are it's like a side bar i was shocked i honestly didn't think you would be able to do it especially since he had said he hadn't really done it before for tiffany it's been shocking to ",
#   'feature': array([[1.85935106e-03, 1.60552619e-04, 5.98557293e-04, ...,
#           2.06150068e-03, 5.76140974e-06, 3.37358308e-03],
#          [1.13857083e-03, 1.62645418e-04, 4.25752049e-04, ...,
#           7.08087930e-04, 1.44430014e-04, 3.09158186e-03],
#          [1.01036183e-03, 1.12039015e-04, 1.01390562e-03, ...,
#           4.31253633e-04, 8.40104243e-04, 2.81493785e-03],
#          ...,
#          [9.56406235e-04, 4.54814908e-05, 1.12726458e-03, ...,
#           1.19826244e-03, 3.66735367e-05, 2.52919155e-03],
#          [9.29209345e-04, 1.63705496e-04, 2.77968147e-03, ...,
#           1.07054343e-03, 3.69139190e-04, 2.39192462e-03],
#          [5.75695187e-04, 4.24277323e-06, 7.86205230e-04, ...,
#           1.31400104e-03, 2.45482399e-04, 2.78457999e-03]], dtype=float32)},
#  'q_XDwC6lyu0_7': {'time': [200.585, 227.735],
#   'cap': "watch her house get into so easily but it's shocking information that she can now use to keep her family safe my family i don't want to have to worry about anyone breaking in and i would definitely consider getting a bump 3 lock now because that way i can know that my family is safer my family safety my stuff that i have in my house i mean it's all of our personal possessions ",
#   'feature': array([[3.5920157e-04, 8.9001340e-05, 9.9612109e-04, ..., 1.4099649e-03,
#           1.9784406e-04, 3.1722994e-03],
#          [4.0654303e-04, 6.4977772e-05, 6.9348299e-04, ..., 1.8741258e-03,
#           9.6717488e-04, 2.1781088e-03],
#          [2.3780033e-04, 5.1678813e-05, 4.2976308e-04, ..., 1.9103768e-03,
#           1.0930564e-03, 2.1265079e-03],
#          ...,
#          [8.7464042e-04, 1.6024557e-04, 2.0286298e-04, ..., 3.9006013e-04,
#           7.1477742e-05, 3.2730885e-03],
#          [1.0750811e-03, 5.0084862e-05, 4.1600212e-04, ..., 6.9057383e-04,
#           1.6657052e-05, 2.7240531e-03],
#          [7.1278570e-05, 5.4580909e-05, 2.2033765e-04, ..., 4.1038590e-04,
#           1.8358306e-04, 3.5327338e-03]], dtype=float32)},
#  'q_XDwC6lyu0_8': {'time': [225.085, 253.115],
#   'cap': "both my kids is safety i mean somebody could get in there and get between us that's scary that's definitely scary scary enough to make some changes it's definitely time to get any locks brandon fonda fox 9 on your side fascinating the bump keys have actually been around for over 50 years but with the internet they've become much more accessible my house a newer house has ",
#   'feature': array([[7.1278570e-05, 5.4580909e-05, 2.2033765e-04, ..., 4.1038590e-04,
#           1.8358306e-04, 3.5327338e-03],
#          [3.0565824e-04, 1.8207014e-04, 5.9591886e-04, ..., 8.5556989e-05,
#           6.8812713e-04, 2.8661531e-03],
#          [1.4531726e-03, 2.0816718e-05, 7.8439881e-04, ..., 1.0681690e-03,
#           1.4421147e-04, 2.7237842e-03],
#          ...,
#          [5.0556811e-04, 2.7835820e-05, 1.2307359e-03, ..., 1.2907049e-03,
#           1.5704823e-05, 2.2956668e-03],
#          [1.1184937e-03, 3.1951906e-05, 1.4851243e-03, ..., 6.8980909e-04,
#           7.3825316e-07, 2.7052385e-03],
#          [9.5120294e-04, 2.0571182e-05, 1.0313288e-03, ..., 1.9272573e-03,
#           4.0409777e-05, 3.0440548e-03]], dtype=float32)},
#  'q_XDwC6lyu0_9': {'time': [250.58, 266.47],
#   'cap': 'the smart keys so i think a lot of the newer construction has that plus have you ever seen those codes you can get the code locks you can do that as well yeah but for those of us who are living in older homes right apparently a bump key is a real problem to take some action ',
#   'feature': array([[9.5120294e-04, 2.0571182e-05, 1.0313288e-03, ..., 1.9272573e-03,
#           4.0409777e-05, 3.0440548e-03],
#          [3.0217154e-04, 2.4313053e-05, 2.3827335e-04, ..., 4.7189102e-04,
#           1.4309649e-04, 2.9045227e-03],
#          [6.0279061e-05, 2.9430853e-04, 1.4254394e-04, ..., 2.3826031e-04,
#           7.6273673e-06, 2.2028710e-03],
#          [2.1293476e-04, 1.8852959e-04, 4.8405545e-05, ..., 5.7008956e-04,
#           7.9978163e-06, 2.1458368e-03],
#          [1.0544275e-04, 1.2406583e-04, 3.1533436e-04, ..., 1.8587091e-04,
#           2.3430851e-04, 2.5230725e-03]], dtype=float32)},
#  'd2GeAvBfnVU_0': {'time': [0.0, 25.54],
#   'cap': "well tonight police are searching for a pair of burglars who tried to break into a home while the homeowner was inside watching from every camera angle had happened in the 600 block of mansfield avenue in hancock park cbs 2's petered out spoke with the homeowner who called 911 what's going on peter pat those burglars certainly picked the wrong house their every move ",
#   'feature': array([[1.73110585e-03, 9.47737590e-06, 4.65515186e-04, ...,
#           1.86886376e-04, 3.61789513e-04, 4.41144686e-03],
#          [9.54793300e-04, 2.65254130e-05, 2.06520228e-04, ...,
#           2.01410599e-04, 7.30503525e-04, 3.22247483e-03],
#          [1.03739114e-03, 2.17200959e-05, 1.23143615e-03, ...,
#           1.77550810e-05, 2.55088635e-05, 3.01290862e-03],
#          [1.05022301e-03, 1.90468010e-04, 6.49385765e-05, ...,
#           8.48947457e-05, 2.37248343e-04, 2.04650452e-03],
#          [3.24908935e-04, 8.29374112e-05, 3.54186690e-04, ...,
#           5.18813846e-04, 3.28300870e-04, 3.10779968e-03],
#          [3.35300632e-04, 1.08812834e-04, 3.66483146e-04, ...,
#           5.11581711e-05, 3.08784774e-06, 2.50068493e-03]], dtype=float32)},
#  'd2GeAvBfnVU_1': {'time': [23.06, 46.965],
#   'cap': 'including when they stopped to pray recorded by multiple security cameras a pair of brazen and bungling burglars caught on camera you can see the kid shaking on the video this homeowner who did not want to show his face says he was inside his hancock park house on march 1st when around 10:30 a.m. this guy knocked on the door no one answers in several ',
#   'feature': array([[3.35300632e-04, 1.08812834e-04, 3.66483146e-04, ...,
#           5.11581711e-05, 3.08784774e-06, 2.50068493e-03],
#          [6.28609923e-05, 9.78839853e-06, 2.26189164e-04, ...,
#           2.87817256e-05, 2.52958009e-04, 3.15821124e-03],
#          [7.79744063e-04, 1.40522407e-05, 5.90200303e-04, ...,
#           6.38746424e-04, 5.52128244e-04, 3.18814255e-03],
#          [9.45872744e-04, 3.81529899e-05, 5.86573035e-04, ...,
#           2.71297613e-04, 4.52633511e-04, 3.99483275e-03],
#          [1.55785866e-03, 9.58120563e-06, 1.45571074e-03, ...,
#           1.02172536e-03, 1.61694887e-04, 2.80273659e-03],
#          [8.07363715e-04, 1.29850741e-04, 8.34181730e-04, ...,
#           1.57388189e-04, 5.51823352e-04, 2.29392177e-03]], dtype=float32)},
#  'd2GeAvBfnVU_2': {'time': [44.945, 68.275],
#   'cap': "minutes later he pulls up in a car with someone else parking right in front of the driveway as neighbors walked by the two eventually get out walk around the side of the house then break into the backyard meanwhile the homeowner is watching them from his computer connected to the security system while on the phone with 911 i'm literally watching them on my cameras they decide ",
#   'feature': array([[1.9508300e-03, 2.5292293e-05, 9.9255727e-04, ..., 6.9732705e-05,
#           9.2398591e-04, 2.2481382e-03],
#          [1.0357142e-03, 1.4419144e-04, 5.3167529e-04, ..., 3.5221566e-04,
#           6.4593548e-04, 2.6154548e-03],
#          [2.5713933e-04, 7.8227720e-05, 2.9214274e-04, ..., 4.5031309e-04,
#           1.0626314e-03, 2.1449467e-03],
#          [1.1261043e-03, 5.4404092e-05, 1.7893789e-04, ..., 5.5903889e-04,
#           9.4535283e-04, 3.1595652e-03],
#          [7.1815331e-04, 1.2234530e-04, 4.6710156e-05, ..., 4.2973013e-04,
#           6.9441600e-04, 2.8162473e-03]], dtype=float32)},
#  'd2GeAvBfnVU_3': {'time': [66.25, 91.21],
#   'cap': "to grab a chair to climb onto the roof but watch what happens next i got a chuckle out of it it didn't make me any less mad undeterred the two then tiptoe to a table and put on gloves the guy in the white shirt holds a screwdriver and tries to pull himself up again the other guy visibly nervous appears to pray and even makes the sign of the cross the fact that he's like ",
#   'feature': array([[4.6241216e-04, 2.3040143e-04, 6.2429497e-04, ..., 6.8194838e-04,
#           4.0474051e-04, 2.9703439e-03],
#          [5.8794194e-05, 2.5698711e-04, 8.2073268e-05, ..., 9.9504665e-05,
#           9.0429472e-04, 2.8404843e-03],
#          [1.1578911e-03, 8.9058005e-05, 1.8931483e-04, ..., 3.2246584e-04,
#           1.3279440e-03, 2.7428111e-03],
#          [7.5609295e-04, 1.4834446e-05, 3.4941669e-04, ..., 1.3595555e-03,
#           3.4208718e-04, 2.3080367e-03],
#          [1.2335577e-04, 5.9546219e-06, 3.7684813e-04, ..., 2.6454104e-04,
#           9.2538430e-05, 2.7016131e-03]], dtype=float32)},
#  'd2GeAvBfnVU_4': {'time': [88.79, 115.165],
#   'cap': "praying to god that he doesn't get caught while he's doing a crime is like unfathomable to me once they break into an upstairs window room the alarm went off which alerted them and the to take off empty-handed the homeowner now has this message for the young burglars if you get caught and you guys are gonna get caught for sure there's a lot of consequences for that ",
#   'feature': array([[1.0765838e-03, 3.8832608e-05, 2.1888880e-04, ..., 2.2929267e-04,
#           1.8131565e-03, 3.1754337e-03],
#          [5.6374632e-04, 9.8768296e-04, 9.7732329e-05, ..., 3.6927543e-04,
#           1.0293290e-03, 2.5423756e-03],
#          [7.9283450e-04, 4.0372257e-04, 5.7354470e-04, ..., 2.1127972e-04,
#           1.4194865e-03, 2.6501806e-03],
#          [7.1893394e-04, 1.6529561e-04, 1.2765804e-04, ..., 4.7635235e-04,
#           5.4679520e-04, 3.2851775e-03],
#          [1.1940729e-03, 4.3655335e-05, 2.3676561e-04, ..., 4.7075388e-05,
#           1.2496046e-03, 2.8388673e-03],
#          [0.0000000e+00, 5.5938304e-05, 9.1021124e-05, ..., 4.3533809e-04,
#           1.2101719e-04, 2.8296956e-03]], dtype=float32)},
#  'd2GeAvBfnVU_5': {'time': [112.8, 127.72],
#   'cap': "the homeowner says this is actually the second time he's been burglarized in less than a year and the suspects in the first case were arrested and he's hoping the same thing happens again in this case reporting live in hancock park petered out cbs 2 news ",
#   'feature': array([[0.0000000e+00, 5.5938304e-05, 9.1021124e-05, ..., 4.3533809e-04,
#           1.2101719e-04, 2.8296956e-03],
#          [1.2021891e-03, 6.5698361e-05, 4.1001625e-04, ..., 4.2574687e-04,
#           8.4903301e-04, 2.4638833e-03],
#          [3.7353826e-04, 1.6513226e-05, 8.4498187e-04, ..., 5.8571786e-06,
#           0.0000000e+00, 3.3792125e-03],
#          [1.3095402e-04, 9.3853349e-05, 6.3156954e-04, ..., 4.7567883e-05,
#           2.5959002e-06, 3.1462123e-03]], dtype=float32)},
#  'hapOJNR-rpI_0': {'time': [4.32, 26.24],
#   'cap': "what they say summer is nearly upon us. is your home. approval you're on vacation? got touch with convicted burglars currently in prison to find out what they thought were the easiest targets, what were the biggest deterrence, and how you can protect your home. ",
#   'feature': array([[5.58215484e-04, 2.06686218e-05, 1.02968515e-04, ...,
#           1.54343623e-04, 1.14306516e-03, 2.17157369e-03],
#          [9.10982955e-04, 4.49218132e-05, 7.65974619e-05, ...,
#           3.73475137e-04, 6.30050839e-04, 2.60029896e-03],
#          [5.71084442e-04, 1.37679177e-04, 1.27911044e-04, ...,
#           3.47734487e-04, 7.93818734e-04, 2.48690695e-03],
#          [9.92917223e-04, 1.03643637e-04, 2.30943697e-04, ...,
#           4.89653321e-04, 5.56269311e-04, 2.40678806e-03],
#          [4.94762571e-05, 0.00000000e+00, 1.57496921e-04, ...,
#           1.96139648e-04, 1.39541808e-04, 2.70918757e-03],
#          [1.47985658e-04, 1.36544827e-07, 1.01034791e-04, ...,
#           1.19948163e-04, 3.50088230e-04, 2.33117072e-03]], dtype=float32)},
#  'hapOJNR-rpI_1': {'time': [25.94, 45.16],
#   'cap': "always lock your outside screen door. you've heard it before, if you are not home, keep your porch light on, or your tv on. does that really deter burglars? i mailed questionnaires to 53 convicted burglars. they also the lights on did not ",
#   'feature': array([[1.76845782e-03, 1.17646952e-04, 2.38633162e-04, ...,
#           6.66447973e-04, 8.07090721e-04, 3.47655732e-03],
#          [4.51795873e-04, 4.89533268e-05, 5.25248121e-04, ...,
#           9.33786330e-04, 2.91196193e-06, 2.91596516e-03],
#          [1.16255687e-04, 0.00000000e+00, 3.84053448e-04, ...,
#           1.80331364e-04, 1.83760785e-04, 2.59241462e-03],
#          [1.23366248e-03, 1.27166149e-05, 7.77671958e-05, ...,
#           8.02910290e-06, 2.92314853e-05, 2.84775719e-03],
#          [1.16226016e-04, 5.33204402e-05, 5.75061858e-05, ...,
#           1.32565224e-03, 7.53156701e-06, 3.08680697e-03],
#          [7.77782174e-04, 4.02558071e-05, 1.30726112e-04, ...,
#           1.40283169e-04, 6.26463734e-04, 2.98111211e-03]], dtype=float32)},
#  'hapOJNR-rpI_2': {'time': [41.69, 63.08],
#   'cap': 'stop them. they broken however they could, kick in a door, smash a window, or find a key. if they go through window, they hurt themselves. they would rather risk kicking in the door then breaking window. i went outside looking for ',
#   'feature': array([[7.77782174e-04, 4.02558071e-05, 1.30726112e-04, ...,
#           1.40283169e-04, 6.26463734e-04, 2.98111211e-03],
#          [7.74097047e-04, 1.55763173e-05, 1.02890037e-04, ...,
#           2.16145709e-04, 1.66904720e-05, 2.38112593e-03],
#          [1.77202921e-04, 1.23298969e-05, 1.63562188e-04, ...,
#           8.01739225e-05, 4.51924541e-04, 2.76100216e-03],
#          [3.31709103e-04, 1.02142461e-04, 2.90934666e-04, ...,
#           2.07681427e-04, 1.16649535e-04, 2.89846631e-03],
#          [1.54124165e-04, 9.10170456e-06, 2.85442919e-04, ...,
#           3.37564910e-04, 1.89719227e-04, 3.09708156e-03],
#          [3.41973559e-04, 0.00000000e+00, 3.88035463e-04, ...,
#           4.77226335e-04, 2.71479166e-05, 3.53099592e-03]], dtype=float32)},
#  'hapOJNR-rpI_3': {'time': [62.18, 76.86],
#   'cap': 'suspicious activity. what is the everything looking for? jewelry or cash. were computers. anything small that they can grab. they can throw in a bag or pillowcase and be gone with it. inmates agree. ',
#   'feature': array([[4.9855291e-05, 0.0000000e+00, 2.9201282e-04, ..., 7.2289848e-05,
#           4.1023869e-04, 3.3611581e-03],
#          [6.1663930e-05, 4.8768275e-06, 2.6495144e-04, ..., 9.2110931e-05,
#           1.8737566e-05, 3.1969934e-03],
#          [3.2776879e-07, 0.0000000e+00, 6.9853559e-04, ..., 2.0303790e-04,
#           9.1244321e-05, 2.7350662e-03],
#          [1.0500691e-03, 1.2364059e-06, 2.8868212e-04, ..., 1.8098348e-04,
#           1.9216411e-04, 2.7758225e-03]], dtype=float32)},
#  'hapOJNR-rpI_4': {'time': [72.92, 97.08],
#   'cap': 'the number one thing they look to steal his cash. one him he told us at the place looks for valuables is the closet. another said everywhere, from the kitchen cabinets to the freezer, vents, even trash cans. do most burglars going the ',
#   'feature': array([[1.0500691e-03, 1.2364059e-06, 2.8868212e-04, ..., 1.8098348e-04,
#           1.9216411e-04, 2.7758225e-03],
#          [7.0906521e-05, 2.0190983e-04, 3.0744082e-04, ..., 5.7052076e-04,
#           3.0087993e-05, 2.2689342e-03],
#          [2.2837315e-03, 0.0000000e+00, 3.2931304e-04, ..., 2.3675021e-03,
#           0.0000000e+00, 2.5258374e-03],
#          ...,
#          [1.0317189e-04, 0.0000000e+00, 1.1768294e-03, ..., 3.3655384e-04,
#           8.1154198e-05, 2.7273579e-03],
#          [2.9232912e-04, 2.7942200e-05, 1.2542075e-03, ..., 3.4013309e-04,
#           1.2854677e-04, 2.4972784e-03],
#          [1.2079501e-04, 7.8225756e-05, 2.5243626e-04, ..., 6.4268395e-05,
#           4.9182578e-05, 2.3592471e-03]], dtype=float32)},
#  'hapOJNR-rpI_5': {'time': [95.85, 116.07],
#   'cap': 'back door the front door? most can the back door. they are not seen from the roadway or the neighbors in the neighborhood. the officer suggests installing motion lights. what are the key things are looking for? first not to see if anyone ',
#   'feature': array([[1.2079501e-04, 7.8225756e-05, 2.5243626e-04, ..., 6.4268395e-05,
#           4.9182578e-05, 2.3592471e-03],
#          [1.7317991e-03, 1.4292404e-04, 5.0229888e-04, ..., 7.2718260e-04,
#           3.4142213e-05, 1.9333516e-03],
#          [7.3742284e-04, 3.0203664e-06, 3.6054326e-04, ..., 3.9787855e-04,
#           1.5029805e-05, 2.4388542e-03],
#          [9.2880189e-04, 3.3910972e-05, 7.5316685e-04, ..., 4.5349944e-04,
#           3.4902222e-04, 2.8740349e-03],
#          [5.9569214e-04, 0.0000000e+00, 2.3398641e-04, ..., 1.0686022e-05,
#           6.4518652e-05, 2.3856985e-03],
#          [1.8643556e-04, 1.5385490e-04, 2.0227506e-04, ..., 3.4006068e-04,
#           1.2150479e-03, 2.6728984e-03]], dtype=float32)},
#  'hapOJNR-rpI_6': {'time': [111.56, 132.75],
#   'cap': 'his home. they to knock on the door to see if anyone is in. the security sign on the door did not stop them. they did say that they would leave if the alarm went off. how about security cameras? we always request a security camera. ',
#   'feature': array([[1.8643556e-04, 1.5385490e-04, 2.0227506e-04, ..., 3.4006068e-04,
#           1.2150479e-03, 2.6728984e-03],
#          [7.6723035e-04, 1.3597232e-04, 4.3670525e-04, ..., 5.5055378e-04,
#           5.7028516e-05, 2.2640410e-03],
#          [1.1344525e-04, 4.5168163e-05, 4.8066213e-04, ..., 3.7278730e-04,
#           1.8886264e-04, 2.0586625e-03],
#          [6.0680805e-04, 9.4292867e-05, 2.8190057e-04, ..., 6.4642599e-04,
#           2.0144694e-04, 1.9859162e-03],
#          [1.8573315e-03, 1.5470870e-05, 3.9727343e-04, ..., 9.6338097e-04,
#           4.2317206e-05, 2.3247954e-03],
#          [6.2815100e-04, 9.1723823e-06, 8.4924395e-04, ..., 3.7718873e-04,
#           1.4675889e-04, 2.4168810e-03]], dtype=float32)},
#  'hapOJNR-rpI_7': {'time': [128.51, 151.73],
#   'cap': 'you can buy economical cameras everywhere and is selling yourself. this one, your doorbell becomes a camera and a speaker. some approaches your door, you learn your phone. you can see them and talk to them without having to go to the door. ',
#   'feature': array([[1.8573315e-03, 1.5470870e-05, 3.9727343e-04, ..., 9.6338097e-04,
#           4.2317206e-05, 2.3247954e-03],
#          [6.2815100e-04, 9.1723823e-06, 8.4924395e-04, ..., 3.7718873e-04,
#           1.4675889e-04, 2.4168810e-03],
#          [1.3473343e-04, 1.9642377e-05, 1.7661834e-04, ..., 4.6942744e-04,
#           1.1169203e-04, 2.4942895e-03],
#          ...,
#          [1.4391926e-04, 3.9267725e-05, 5.5621786e-04, ..., 2.6756618e-04,
#           4.8664492e-04, 2.6344506e-03],
#          [6.1540643e-04, 3.9330320e-05, 4.0782249e-04, ..., 7.1694108e-04,
#           1.9975792e-05, 2.7848182e-03],
#          [3.9189588e-04, 4.1533352e-04, 6.2946769e-05, ..., 3.1733001e-04,
#           5.3623068e-04, 2.6025360e-03]], dtype=float32)},
#  'hapOJNR-rpI_8': {'time': [149.7, 164.15],
#   'cap': 'you do not have to be home, but they do not need to know that. we put security cameras up, make sure that they are placed in the right places. where you have a door that is used the most is what i would say. front, side, or if you have enough cameras, put it at the ',
#   'feature': array([[3.91895883e-04, 4.15333518e-04, 6.29467686e-05, ...,
#           3.17330007e-04, 5.36230684e-04, 2.60253600e-03],
#          [1.24932954e-03, 3.67829314e-04, 3.14062956e-04, ...,
#           4.42619639e-04, 9.29627917e-04, 2.35447008e-03],
#          [2.99242616e-04, 1.74010711e-04, 5.13596868e-04, ...,
#           2.03390184e-04, 8.87160597e-04, 2.12737080e-03],
#          [3.60400503e-04, 2.43067620e-06, 1.23377540e-04, ...,
#           1.78444578e-04, 3.52961157e-04, 2.32032337e-03],
#          [2.85806716e-04, 1.20279095e-04, 3.65378160e-04, ...,
#           9.13670170e-04, 1.06002751e-03, 2.19999067e-03]], dtype=float32)},
#  'hapOJNR-rpI_9': {'time': [161.11, 179.5],
#   'cap': 'back door. a lot of criminals use the glass doors. i recommend putting a broomstick or some kind of handle that when they open it, they cannot get it all the way open. officer lee suggested getting a dog. ',
#   'feature': array([[2.85806716e-04, 1.20279095e-04, 3.65378160e-04, ...,
#           9.13670170e-04, 1.06002751e-03, 2.19999067e-03],
#          [3.36450612e-05, 0.00000000e+00, 5.48135606e-04, ...,
#           4.65553196e-04, 4.50391999e-05, 2.61135353e-03],
#          [3.63776868e-04, 4.42710807e-05, 6.32041076e-04, ...,
#           5.02765237e-04, 4.92091640e-04, 2.74550868e-03],
#          [0.00000000e+00, 0.00000000e+00, 5.54765225e-04, ...,
#           5.07437944e-05, 1.77401642e-04, 2.88461987e-03],
#          [8.07989272e-05, 0.00000000e+00, 1.71715365e-04, ...,
#           2.57983447e-05, 6.59929065e-05, 2.96482211e-03]], dtype=float32)},
#  'hapOJNR-rpI_10': {'time': [176.13, 197.65],
#   'cap': "when inmate told us that it made him think twice.'s -- because a barking dog attracts attention. but he said that if i want to go in, i will befriend your dog or kill it if i had to. officer lee says be proactive. you recommend security cameras, low bushes? ",
#   'feature': array([[8.0798927e-05, 0.0000000e+00, 1.7171536e-04, ..., 2.5798345e-05,
#           6.5992906e-05, 2.9648221e-03],
#          [2.9925781e-04, 2.5361601e-06, 3.5324821e-04, ..., 8.4387342e-05,
#           1.1565390e-03, 2.5472289e-03],
#          [4.0186921e-04, 2.0418802e-05, 4.4035900e-04, ..., 2.5592122e-04,
#           7.5458188e-04, 2.8389734e-03],
#          [1.7284215e-04, 0.0000000e+00, 3.9248349e-04, ..., 1.1286670e-04,
#           9.6386060e-04, 3.8578506e-03],
#          [7.9332170e-04, 7.4382256e-06, 3.3373595e-04, ..., 3.4411284e-04,
#           7.7946123e-04, 2.8198371e-03],
#          [1.0515763e-04, 0.0000000e+00, 4.0330825e-04, ..., 1.4304445e-04,
#           4.7397247e-04, 2.2247289e-03]], dtype=float32)},
#  'hapOJNR-rpI_11': {'time': [196.11, 211.51],
#   'cap': 'lights? good lights? good locks. make sure that your trashcan is not left on the curb and the post office hold your mail. make your home visible. this is often overlooked. if you crawlspace, sure you ',
#   'feature': array([[1.7143921e-03, 2.1270400e-05, 2.0557802e-05, ..., 3.2098320e-05,
#           3.8868362e-05, 2.2783752e-03],
#          [3.6628207e-04, 3.7630016e-05, 1.2482080e-04, ..., 6.5221434e-04,
#           1.7003788e-04, 2.8424638e-03],
#          [1.0248292e-03, 4.3717260e-05, 5.0267956e-04, ..., 1.4495616e-03,
#           2.0378109e-05, 1.7722296e-03],
#          [1.1461751e-03, 0.0000000e+00, 1.8894722e-04, ..., 4.7639286e-04,
#           5.2692636e-04, 2.3961072e-03]], dtype=float32)},
#  'HCHKifNwS3Q_0': {'time': [0.0, 58.505],
#   'cap': "hi guys welcome back today's episode we're going to talk about snake repellers and how they don't work i'm going to show you better ways to invest your money around your home to snake through foot or better man for the job and ian renton and snake waste services  what an annoying time imagine having these last you're around ",
#   'feature': array([[1.4000334e-03, 0.0000000e+00, 3.6044366e-04, ..., 1.7184833e-05,
#           6.8529585e-04, 3.1067492e-03],
#          [1.4049604e-03, 3.1912990e-05, 5.8312173e-04, ..., 1.8303831e-04,
#           2.1677117e-05, 2.2090396e-03],
#          [8.9779333e-04, 9.7746833e-06, 7.1217597e-05, ..., 8.2029674e-06,
#           1.2470395e-03, 2.1738715e-03],
#          ...,
#          [2.5274299e-04, 4.0143394e-05, 4.3559128e-05, ..., 8.6148421e-04,
#           1.0733746e-03, 2.3218601e-03],
#          [8.9107896e-04, 0.0000000e+00, 3.0893111e-04, ..., 2.1887381e-04,
#           5.8265059e-04, 2.1534597e-03],
#          [3.6383193e-04, 1.8451273e-04, 2.2009264e-04, ..., 4.5968365e-04,
#           3.1085423e-04, 1.8380594e-03]], dtype=float32)},
#  'HCHKifNwS3Q_1': {'time': [55.17, 93.325],
#   'cap': "yes this is a solar snake repeller i sell them through various hardware stores pet chains over the internet through gumtree facebook they supposedly work by sending out a vibration through the stem of this repeller also with the beeping tone as you heard which will interrupt me very shortly between the two on cue that is supposed to scare a snake off now i can't even feel the ",
#   'feature': array([[3.6383193e-04, 1.8451273e-04, 2.2009264e-04, ..., 4.5968365e-04,
#           3.1085423e-04, 1.8380594e-03],
#          [2.4428422e-04, 3.1815766e-04, 1.0477385e-04, ..., 4.3619541e-04,
#           2.7704047e-04, 1.9821930e-03],
#          [5.5933150e-04, 6.5655542e-05, 4.5936042e-05, ..., 3.0946769e-04,
#           1.2919650e-03, 1.8316794e-03],
#          ...,
#          [3.1333134e-04, 2.8424643e-04, 2.4285924e-04, ..., 1.5524427e-04,
#           2.1365723e-03, 2.2639947e-03],
#          [2.0951639e-04, 7.3888805e-05, 1.2986778e-04, ..., 9.0995512e-05,
#           2.5607508e-03, 2.1695241e-03],
#          [2.6968960e-04, 3.9310750e-04, 4.0442144e-04, ..., 1.4665286e-04,
#           1.4133486e-03, 2.2331257e-03]], dtype=float32)},
#  'HCHKifNwS3Q_2': {'time': [90.805, 123.595],
#   'cap': "vibration that is coming out of this all it is is a solar powered unit on top which is used to charge a battery which generally goes inside this one hasn't got it but it's got a connection which pulls apart the battery goes down inside it's a rechargeable battery and they go into the ground up to about sadie there's many a call that we go to and attend where people have actually got ",
#   'feature': array([[2.69689597e-04, 3.93107504e-04, 4.04421444e-04, ...,
#           1.46652863e-04, 1.41334860e-03, 2.23312574e-03],
#          [4.69994731e-04, 6.70092850e-05, 4.48285224e-04, ...,
#           3.44587723e-04, 5.85041125e-04, 2.30846531e-03],
#          [5.61266264e-04, 1.17277174e-04, 6.78245211e-04, ...,
#           6.29888746e-05, 1.00602349e-03, 2.75364378e-03],
#          ...,
#          [5.47479198e-04, 2.26877339e-04, 1.01494894e-04, ...,
#           2.75207276e-04, 7.38234667e-04, 2.18344014e-03],
#          [8.11583246e-04, 3.08828545e-04, 1.94418666e-04, ...,
#           1.77983937e-04, 1.55724993e-03, 1.62271899e-03],
#          [4.10383975e-04, 2.08453042e-04, 7.54475914e-05, ...,
#           1.69309074e-04, 4.28386673e-04, 2.00463692e-03]], dtype=float32)},
#  'HCHKifNwS3Q_3': {'time': [120.805, 149.305],
#   'cap': "these and snakes curled up in around them or on top of them generally in that light in south australia because they're venomous snakes that we've got these are providing shelter so snake actually go and curl up around underneath it to get the shade they say need between four and six around a property and that time going off all the time imagine what you and your neighbors are putting up with ",
#   'feature': array([[4.1038397e-04, 2.0845304e-04, 7.5447591e-05, ..., 1.6930907e-04,
#           4.2838667e-04, 2.0046369e-03],
#          [1.2393965e-03, 2.1945842e-05, 1.6814476e-04, ..., 3.1312692e-04,
#           5.9806940e-04, 2.1048361e-03],
#          [5.7474524e-04, 4.3786615e-05, 2.2222429e-04, ..., 5.9610850e-04,
#           1.7928338e-03, 2.2349656e-03],
#          ...,
#          [8.1277080e-04, 1.8381805e-05, 2.6897405e-04, ..., 2.4448009e-04,
#           8.4664591e-04, 2.1127425e-03],
#          [1.5083631e-04, 2.7752347e-05, 2.1377903e-04, ..., 2.6138523e-04,
#           1.5598289e-03, 2.3822109e-03],
#          [2.2858838e-04, 3.7794060e-05, 1.5128721e-04, ..., 1.9331081e-04,
#           9.5063727e-04, 2.5259464e-03]], dtype=float32)},
#  'HCHKifNwS3Q_4': {'time': [146.35, 176.13],
#   'cap': "24 hours a day turn it off by all means but then as soon as you turn it off the makers of these things will turn around and say but you turned it off so that's why the snake came then you've got other ones they work a little bit differently these have just got a battery inside of them or a couple of batteries doublea's wide as you can see a little bit of electronics in the bottom of it it sends ",
#   'feature': array([[1.78625109e-04, 2.53793223e-05, 2.53359554e-04, ...,
#           6.72617607e-05, 1.38664548e-03, 2.58945511e-03],
#          [5.07805496e-04, 4.91441097e-06, 2.29477097e-04, ...,
#           1.92355932e-04, 8.72634409e-04, 2.31979811e-03],
#          [3.17773985e-04, 0.00000000e+00, 3.87464243e-05, ...,
#           1.63902208e-04, 1.83872273e-03, 2.15218705e-03],
#          ...,
#          [1.42616336e-03, 9.38322773e-05, 4.01284778e-04, ...,
#           2.69435550e-04, 1.10973255e-03, 2.51673628e-03],
#          [1.08492607e-03, 1.02285776e-04, 3.51300143e-04, ...,
#           1.73117471e-04, 1.83511782e-03, 1.86081312e-03],
#          [9.00734100e-04, 2.13642823e-04, 2.16247514e-04, ...,
#           1.87003112e-04, 5.61366440e-04, 2.82914494e-03]], dtype=float32)},
#  'HCHKifNwS3Q_5': {'time': [173.565, 210.85],
#   'cap': "out of beeping noise again this one doesn't even do pulsating it says it does but they don't so you don't need the solar panel on top but both of them waste our money 30 40 50 dollars up to 100 dollars a pair but around 30 40 dollars for a single one i come in boxes like such okay as we also saw for this one not worth the money there's other things that can be done that you can ",
#   'feature': array([[9.0073410e-04, 2.1364282e-04, 2.1624751e-04, ..., 1.8700311e-04,
#           5.6136644e-04, 2.8291449e-03],
#          [2.7678793e-04, 9.7092321e-05, 3.0929566e-04, ..., 1.6074050e-04,
#           1.3638880e-03, 2.4753548e-03],
#          [1.3075187e-04, 1.9574316e-05, 2.7858914e-04, ..., 1.4708511e-04,
#           1.6781532e-03, 2.6817289e-03],
#          ...,
#          [2.6185255e-04, 2.3638413e-04, 2.8369372e-05, ..., 2.3918050e-04,
#           1.6891110e-03, 2.3645009e-03],
#          [1.3619419e-03, 5.8807323e-06, 1.2954714e-04, ..., 4.0597333e-05,
#           9.2004228e-04, 2.4839675e-03],
#          [7.7418250e-04, 5.4103177e-05, 2.4968281e-04, ..., 1.5062977e-04,
#           1.6667921e-03, 2.2930172e-03]], dtype=float32)},
#  'HCHKifNwS3Q_6': {'time': [207.265, 237.675],
#   'cap': "make your yard and your home a lot safer on the other hand we've also got liquid repellents you spray this stuff around you're going to be safe from a snake because of is that putrid you're not even going to be there so the snake can happily move around your home another one we've got which comes from america both of these are highly toxic this one's made out of sulfur and naphthalene ",
#   'feature': array([[7.74182496e-04, 5.41031768e-05, 2.49682809e-04, ...,
#           1.50629770e-04, 1.66679209e-03, 2.29301723e-03],
#          [1.00439717e-03, 9.60150064e-05, 3.44890461e-04, ...,
#           1.10018387e-04, 2.79890280e-03, 2.46368069e-03],
#          [4.42201854e-04, 2.34278690e-04, 2.89679534e-04, ...,
#           1.15233335e-04, 1.82716642e-03, 2.30387296e-03],
#          ...,
#          [1.65540422e-03, 5.98000915e-05, 4.44410631e-04, ...,
#           1.52879496e-04, 7.09291839e-04, 2.03450909e-03],
#          [9.97267081e-04, 4.24510945e-05, 1.73924112e-04, ...,
#           5.28207456e-04, 1.43259438e-03, 1.91604416e-03],
#          [4.66083642e-04, 1.96622394e-04, 3.92482820e-04, ...,
#           3.28455877e-04, 1.93568901e-03, 2.42535025e-03]], dtype=float32)},
#  'HCHKifNwS3Q_7': {'time': [235.48, 262.705],
#   'cap': "you imagine sprinkling naphthalene all around your yard i've had people ring up saying i've had to scrape off six inches of topsoil to get rid of the smell of the naphthalene this guy was in america but there's other things that you can do around your home you can do yourself all of snake way services team members all our subcontractors they're all qualified to ",
#   'feature': array([[4.66083642e-04, 1.96622394e-04, 3.92482820e-04, ...,
#           3.28455877e-04, 1.93568901e-03, 2.42535025e-03],
#          [5.68294083e-04, 2.63903115e-04, 1.01341517e-04, ...,
#           3.24841414e-04, 2.14107521e-03, 2.27199984e-03],
#          [1.37836370e-03, 4.51247106e-05, 2.82593654e-04, ...,
#           1.04650142e-04, 1.87838450e-03, 2.30619987e-03],
#          ...,
#          [3.22538224e-04, 1.14960523e-04, 2.98447529e-04, ...,
#           7.46099511e-04, 2.56334199e-03, 1.96590298e-03],
#          [4.59498435e-04, 1.07632814e-05, 1.07599633e-04, ...,
#           4.56900889e-04, 7.99837871e-04, 2.26809457e-03],
#          [6.49192370e-04, 1.71652446e-05, 1.03013597e-04, ...,
#           1.10317706e-04, 1.73103344e-03, 2.20079022e-03]], dtype=float32)},
#  'HCHKifNwS3Q_8': {'time': [260.545, 290.96],
#   'cap': 'do this and they can help out if needed but there are things that you can do yourself simple little things like vermin mesh herpetologist people like myself we actually make cages out of it to protect our snakes from getting burned it forms it goes up under the heat globe or over the heat globe and that way it protects the snake from getting work ',
#   'feature': array([[6.49192370e-04, 1.71652446e-05, 1.03013597e-04, ...,
#           1.10317706e-04, 1.73103344e-03, 2.20079022e-03],
#          [6.31319999e-05, 1.27453022e-04, 1.90805615e-04, ...,
#           1.10369358e-04, 1.50301983e-03, 2.38658441e-03],
#          [3.56970500e-04, 3.34934681e-04, 5.53103280e-04, ...,
#           1.50436026e-04, 1.60509674e-03, 2.13106303e-03],
#          ...,
#          [2.32914870e-04, 7.35394569e-05, 1.91648447e-04, ...,
#           6.40216866e-04, 1.23081775e-03, 3.11469613e-03],
#          [1.54972426e-03, 2.21185724e-06, 2.24674965e-04, ...,
#           7.82614341e-04, 5.07989142e-04, 1.91733835e-03],
#          [4.48753912e-04, 2.05691889e-04, 2.33324230e-04, ...,
#           2.07701785e-04, 2.53695529e-04, 2.00618082e-03]], dtype=float32)},
#  'HCHKifNwS3Q_9': {'time': [287.3, 317.205],
#   'cap': "the bow but you can use it to block up areas around your yard holes in your fence gaps up at the end of you where your fence joins your back bench side fence into your back fence anywhere like that that can be covered up to prevent snakes getting through even juvenile brown snakes cannot get through this it's six millimeter square another one which is very very handy is this ",
#   'feature': array([[1.5497243e-03, 2.2118572e-06, 2.2467496e-04, ..., 7.8261434e-04,
#           5.0798914e-04, 1.9173383e-03],
#          [4.4875391e-04, 2.0569189e-04, 2.3332423e-04, ..., 2.0770179e-04,
#           2.5369553e-04, 2.0061808e-03],
#          [5.0909328e-04, 2.2249967e-04, 1.5573588e-04, ..., 2.1259533e-04,
#           2.9607897e-04, 2.1264153e-03],
#          ...,
#          [6.2430411e-04, 9.1741793e-05, 1.9598909e-04, ..., 8.5509848e-05,
#           3.1753518e-03, 2.2038724e-03],
#          [1.9292373e-04, 3.4321201e-05, 1.2772423e-04, ..., 1.1692451e-04,
#           7.9077645e-04, 2.3796405e-03],
#          [4.7565252e-04, 2.9901892e-05, 1.7686961e-04, ..., 1.3937888e-04,
#           1.6574069e-03, 2.0963755e-03]], dtype=float32)},
#  'HCHKifNwS3Q_10': {'time': [314.62, 348.825],
#   'cap': "aluminium mesh that you can get from various security screen door manufacturers this can be molded in various ways to go over your vents on the outside of your brick wall you can get a a piece of doubt or quarter-inch timber and make a mold out of it put it over the top to create something like this right same shape cut it to length that's the length of your brick then ",
#   'feature': array([[4.7565252e-04, 2.9901892e-05, 1.7686961e-04, ..., 1.3937888e-04,
#           1.6574069e-03, 2.0963755e-03],
#          [1.5613066e-04, 7.3012779e-05, 4.6928653e-05, ..., 1.9160541e-05,
#           1.5545624e-03, 2.1466315e-03],
#          [6.5894780e-04, 2.6223574e-05, 5.6456443e-04, ..., 1.8364098e-04,
#           2.3451466e-03, 2.1072109e-03],
#          ...,
#          [6.4547901e-04, 8.7986678e-05, 1.6397022e-04, ..., 2.7092901e-04,
#           1.3217751e-03, 2.1976861e-03],
#          [8.8589988e-04, 7.7693021e-06, 1.3476846e-04, ..., 1.0948874e-04,
#           1.1292621e-03, 2.0604804e-03],
#          [2.6159789e-04, 6.3224594e-05, 1.2290967e-04, ..., 1.7286641e-04,
#           3.7860736e-04, 1.6846729e-03]], dtype=float32)},
#  'HCHKifNwS3Q_11': {'time': [346.32, 380.865],
#   'cap': "that can be slotted into your weep holes or perp jeans most new houses have got one today there's a newer modern one on the market what we used to use is this little fella it's a plastic mold but it only lasts about five years it slots into the perp joint or weep holes around the house it still allows for the ventilation and the drainage but it stops millipedes mice spiders snakes ",
#   'feature': array([[2.61597888e-04, 6.32245938e-05, 1.22909667e-04, ...,
#           1.72866407e-04, 3.78607365e-04, 1.68467290e-03],
#          [9.26843670e-04, 3.58982277e-07, 1.31073961e-04, ...,
#           2.00328475e-04, 1.98440626e-03, 2.19995482e-03],
#          [7.36991875e-04, 2.84371595e-06, 7.71666091e-05, ...,
#           2.64213915e-04, 2.17456138e-03, 2.51626922e-03],
#          ...,
#          [4.36551491e-04, 6.63741375e-05, 1.21207588e-04, ...,
#           6.29849732e-04, 1.55540812e-03, 2.18837359e-03],
#          [4.59054543e-04, 1.26852626e-06, 4.00870340e-04, ...,
#           3.03119101e-04, 2.46426649e-03, 2.72712647e-03],
#          [1.22473377e-03, 2.44022885e-06, 1.13532085e-04, ...,
#           1.43964513e-04, 1.64640811e-03, 2.12332932e-03]], dtype=float32)},
#  'HCHKifNwS3Q_12': {'time': [378.475, 414.725],
#   'cap': "getting into the walls of the house consequently giving them more access into your home these are superseded now we've got the newer items the stainless steel filters okay they even come with their own applicator which sits in as such and then that can be slotted in into the weep hole or the pep joint and we'll show some of those applications shirley actually come in in packs of 20 ",
#   'feature': array([[1.22473377e-03, 2.44022885e-06, 1.13532085e-04, ...,
#           1.43964513e-04, 1.64640811e-03, 2.12332932e-03],
#          [2.02545634e-04, 0.00000000e+00, 1.53787390e-04, ...,
#           2.82221357e-04, 7.81039940e-04, 2.00579292e-03],
#          [7.15706323e-04, 3.31568517e-05, 1.53203044e-04, ...,
#           7.46133883e-05, 1.83327007e-03, 2.10741255e-03],
#          ...,
#          [1.11563364e-03, 7.71139457e-05, 3.79394158e-04, ...,
#           6.55254815e-04, 1.75388111e-03, 2.49092816e-03],
#          [1.86047330e-03, 1.57680013e-04, 2.16768938e-04, ...,
#           5.05318982e-04, 2.36027897e-03, 2.37710751e-03],
#          [6.98720862e-04, 2.88964693e-05, 2.18860834e-04, ...,
#           1.45776634e-04, 1.08275353e-03, 2.71086418e-03]], dtype=float32)},
#  'HCHKifNwS3Q_13': {'time': [412.22, 440.615],
#   'cap': 'with their own applicator all snake away contractors actually carry them and as i said we can fit them for you or you can do it yourself saving some money now around the home rodent eradication is a main thing that safeguards your house if you allow mice and rats to breed around your home sooner or later you are going to attract a snake the average size brown snake of ',
#   'feature': array([[6.9872086e-04, 2.8896469e-05, 2.1886083e-04, ..., 1.4577663e-04,
#           1.0827535e-03, 2.7108642e-03],
#          [6.3840131e-04, 4.9921371e-05, 2.7585591e-04, ..., 6.7630806e-04,
#           2.0318083e-03, 2.3164898e-03],
#          [5.1361066e-04, 1.4122485e-04, 3.1252773e-04, ..., 8.7896828e-04,
#           3.1120586e-03, 2.2063609e-03],
#          ...,
#          [4.4374453e-04, 1.0234873e-05, 2.0522588e-04, ..., 7.6746393e-04,
#           1.7965834e-03, 2.1871063e-03],
#          [5.0816516e-04, 1.4767526e-05, 2.8261193e-04, ..., 6.6351367e-04,
#           1.4210374e-03, 1.7934282e-03],
#          [3.9694976e-04, 0.0000000e+00, 1.7047068e-04, ..., 5.4625631e-04,
#           1.0574128e-03, 2.1922351e-03]], dtype=float32)},
#  'HCHKifNwS3Q_14': {'time': [438.2, 465.575],
#   'cap': "a meter and above can cover in excess of a kilometer a day in such a food now if it comes across the trail of a mouse that has run along and it's gone into the joints of your wall in your house or anywhere else anywhere a mouse goes it leaves a scent trail the snake in covering its territory a day of over a kilometre if it comes across that scent trail it will turn around and follow ",
#   'feature': array([[3.9694976e-04, 0.0000000e+00, 1.7047068e-04, ..., 5.4625631e-04,
#           1.0574128e-03, 2.1922351e-03],
#          [7.8082038e-04, 6.6762505e-07, 3.8495407e-04, ..., 7.9410896e-04,
#           1.8004858e-03, 2.0298623e-03],
#          [5.3866062e-04, 3.2769731e-05, 1.5340606e-04, ..., 7.6901121e-04,
#           1.8452792e-03, 2.1415451e-03],
#          ...,
#          [5.2926136e-04, 5.6464387e-07, 1.4918715e-04, ..., 1.0862777e-03,
#           1.0041626e-03, 1.9252057e-03],
#          [4.7787651e-04, 8.3216255e-06, 2.4271809e-04, ..., 7.0805184e-04,
#           1.4604559e-03, 2.1247626e-03],
#          [4.7916523e-04, 6.3977874e-05, 2.3250970e-04, ..., 9.3670463e-04,
#           8.5048378e-04, 2.3828926e-03]], dtype=float32)},
#  'HCHKifNwS3Q_15': {'time': [462.83, 487.79],
# ...
#           1.7561493e-03, 3.1323864e-03]], dtype=float32)},
#  '148PFguTmNg_9': {'time': [169.84, 187.33],
#   'cap': "them down to to be tested bench testers and afterwards they'll be rebuilt like i and afterwards they'll be rebuilt like i   and afterwards they'll be rebuilt like i said if they can be or they will be said if they can be or they will be   said if they can be or they will be replaced now if you were carrying out replaced now if you were carrying out   replaced now if you were carrying out this test and you just want to do a this test and you just want to do a   this test and you just want to do a quick test that is now the back leakage quick test that is now the back leakage   ",
#   'feature': array([[1.1448225e-03, 1.4439158e-05, 1.1242502e-04, ..., 9.1025257e-04,
#           1.7561493e-03, 3.1323864e-03],
#          [1.7190268e-03, 0.0000000e+00, 8.9508947e-05, ..., 4.8752705e-04,
#           1.9871215e-03, 3.0493306e-03],
#          [2.0822957e-03, 0.0000000e+00, 6.4694177e-04, ..., 3.0515026e-04,
#           6.1321846e-04, 3.1149331e-03],
#          [1.1621912e-03, 6.1173901e-06, 3.3915520e-04, ..., 2.0341299e-04,
#           8.0576964e-04, 3.1484035e-03],
#          [1.7679471e-04, 8.5499796e-06, 9.5987174e-04, ..., 2.9701428e-04,
#           8.4906921e-04, 2.6478779e-03],
#          [4.3499272e-04, 9.9887411e-06, 8.9927495e-04, ..., 3.5983330e-04,
#           6.3302473e-04, 2.4348234e-03]], dtype=float32)},
#  '148PFguTmNg_10': {'time': [182.45, 200.25],
#   'cap': "quick test that is now the back leakage test completed and this is the kit that test completed and this is the kit that   test completed and this is the kit that i was using pencil if you didn't have i was using pencil if you didn't have   i was using pencil if you didn't have the same type of injector setup as i the same type of injector setup as i   the same type of injector setup as i have that one and these are the fittings have that one and these are the fittings   have that one and these are the fittings that you will be using for the other that you will be using for the other   ",
#   'feature': array([[1.7679471e-04, 8.5499796e-06, 9.5987174e-04, ..., 2.9701428e-04,
#           8.4906921e-04, 2.6478779e-03],
#          [4.3499272e-04, 9.9887411e-06, 8.9927495e-04, ..., 3.5983330e-04,
#           6.3302473e-04, 2.4348234e-03],
#          [2.1089627e-04, 4.3450782e-05, 3.3087112e-04, ..., 3.9207615e-04,
#           1.0720994e-03, 2.2035073e-03],
#          [5.4734899e-04, 4.4497374e-06, 2.0338828e-04, ..., 2.2352574e-04,
#           3.2944794e-04, 2.8233123e-03],
#          [2.7547727e-04, 8.1936578e-06, 3.6289933e-04, ..., 1.1748471e-05,
#           1.3751130e-03, 2.9048773e-03],
#          [1.3031652e-03, 0.0000000e+00, 3.5321480e-04, ..., 6.7738943e-06,
#           1.2833503e-04, 2.9520812e-03]], dtype=float32)},
#  '148PFguTmNg_11': {'time': [196.97, 215.97],
#   'cap': 'that you will be using for the other type a few different types and then for type a few different types and then for   type a few different types and then for the non start you can also use these the non start you can also use these   the non start you can also use these smaller tubes for for measurement okay smaller tubes for for measurement okay   smaller tubes for for measurement okay so with all the tests complete we have so with all the tests complete we have   so with all the tests complete we have showed that the injectors do have showed that the injectors do have   ',
#   'feature': array([[1.3031652e-03, 0.0000000e+00, 3.5321480e-04, ..., 6.7738943e-06,
#           1.2833503e-04, 2.9520812e-03],
#          [9.5256051e-04, 4.4999356e-06, 4.2032957e-04, ..., 2.5590099e-04,
#           1.1010671e-03, 2.5431402e-03],
#          [1.6897044e-03, 4.3259963e-05, 1.1851618e-05, ..., 2.7109738e-04,
#           2.0113734e-03, 1.9347034e-03],
#          [1.2150900e-03, 1.5872315e-04, 2.3361485e-05, ..., 1.8472187e-04,
#           1.2519106e-03, 2.3333929e-03],
#          [1.4859324e-03, 1.8016322e-04, 2.2285290e-05, ..., 2.3896701e-04,
#           4.9893296e-04, 1.9826361e-03],
#          [9.2190580e-04, 4.3889249e-05, 6.3312391e-06, ..., 2.6094487e-05,
#           1.3193504e-03, 2.3157976e-03]], dtype=float32)},
#  '148PFguTmNg_12': {'time': [213.5, 231.42],
#   'cap': 'showed that the injectors do have excessive back late age and reason for excessive back late age and reason for   excessive back late age and reason for that can be an internal erosion in the that can be an internal erosion in the   that can be an internal erosion in the voltage which causes the pressure to voltage which causes the pressure to   voltage which causes the pressure to drop off and the rail and for extra fuel drop off and the rail and for extra fuel   drop off and the rail and for extra fuel to be returning to the lines and to be returning to the lines and   ',
#   'feature': array([[9.2190580e-04, 4.3889249e-05, 6.3312391e-06, ..., 2.6094487e-05,
#           1.3193504e-03, 2.3157976e-03],
#          [1.0661611e-03, 1.1185764e-04, 1.5670259e-05, ..., 7.2865914e-05,
#           9.6412963e-04, 2.2734185e-03],
#          [9.2363078e-04, 0.0000000e+00, 1.1234292e-06, ..., 2.8149227e-05,
#           1.4407162e-03, 2.0765490e-03],
#          [1.2492773e-03, 3.0675007e-04, 4.3771121e-05, ..., 2.9009284e-04,
#           7.0996577e-04, 1.9627232e-03],
#          [8.6013187e-04, 2.4193709e-04, 3.2768567e-05, ..., 2.7931080e-04,
#           5.1212916e-04, 1.7693546e-03],
#          [1.2663228e-03, 7.2823306e-05, 4.0552870e-05, ..., 1.3297109e-04,
#           1.4296272e-03, 1.9827490e-03]], dtype=float32)},
#  '148PFguTmNg_13': {'time': [228.0, 243.3],
#   'cap': 'to be returning to the lines and basically so the next stage with this m basically so the next stage with this m   basically so the next stage with this m will be to bring bring them injectors will be to bring bring them injectors   will be to bring bring them injectors get them getting rebuilt or get them get them getting rebuilt or get them   get them getting rebuilt or get them replaced pretty much you can do a pinch replaced pretty much you can do a pinch   replaced pretty much you can do a pinch test on them just to make totally test on them just to make totally   ',
#   'feature': array([[1.26632280e-03, 7.28233063e-05, 4.05528699e-05, ...,
#           1.32971094e-04, 1.42962718e-03, 1.98274897e-03],
#          [1.36061478e-03, 3.66459164e-04, 9.99285567e-06, ...,
#           1.12185124e-04, 8.13593913e-04, 2.08740821e-03],
#          [1.31312967e-03, 2.63490627e-04, 4.47751017e-06, ...,
#           1.49299158e-04, 1.66345784e-03, 2.23733997e-03],
#          [1.40162348e-03, 3.34455632e-04, 2.73812548e-05, ...,
#           1.37398485e-04, 5.90775511e-04, 2.22196267e-03]], dtype=float32)},
#  '148PFguTmNg_14': {'time': [241.04, 256.14],
#   'cap': "test on them just to make totally certain that everything's good but i'm certain that everything's good but i'm   certain that everything's good but i'm pretty convinced with that test that we pretty convinced with that test that we   pretty convinced with that test that we do need to replace a minimum of two do need to replace a minimum of two   do need to replace a minimum of two injectors okay so that's the test injectors okay so that's the test   injectors okay so that's the test complete complete   ",
#   'feature': array([[9.6886896e-04, 4.0378826e-04, 3.7621371e-06, ..., 1.8204458e-04,
#           6.7468622e-04, 2.4480419e-03],
#          [1.0681837e-03, 5.5801876e-05, 1.8128977e-06, ..., 1.0956189e-04,
#           1.6147175e-03, 2.3269972e-03],
#          [1.0421291e-03, 5.3599906e-05, 1.5914960e-05, ..., 6.3166008e-05,
#           2.1788781e-03, 2.0012413e-03],
#          [6.0315290e-04, 1.8904946e-04, 2.5812087e-06, ..., 4.6558773e-05,
#           2.1174939e-03, 2.1767339e-03]], dtype=float32)},
#  '148PFguTmNg_15': {'time': [253.54, 264.13],
#   'cap': 'complete i hope you found this video useful if i hope you found this video useful if   i hope you found this video useful if you did please like share comment and you did please like share comment and   you did please like share comment and subscribe and i hope to see you in the subscribe and i hope to see you in the   subscribe and i hope to see you in the next one thanks for watching next one thanks for watching   next one thanks for watching oh ',
#   'feature': array([[1.2301181e-03, 3.9884372e-04, 6.8238252e-05, ..., 8.7208563e-04,
#           1.2806598e-03, 2.3610243e-03],
#          [6.1665347e-04, 6.1324368e-05, 2.9601340e-04, ..., 4.3708613e-05,
#           1.6961466e-03, 1.4277992e-03],
#          [4.7759368e-04, 5.7401648e-04, 4.1328726e-04, ..., 6.2823581e-04,
#           2.0204305e-04, 1.1586980e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_0': {'time': [5.03, 31.73],
#   'cap': "- that's true. [pounding at door] - it's your landlord! [pounding continues] - hey, devon. - hey, how you doing, brother? how you doing? yeah. just, uh, stopping by. just wanted to check up on everything. - okay. - yeah--aha! you in here, you little mother[bleep]? ",
#   'feature': array([[1.6777866e-03, 1.4436079e-04, 2.9246550e-04, ..., 1.5671844e-04,
#           1.2876636e-03, 1.8783426e-03],
#          [9.1587310e-04, 2.7036385e-05, 1.2140429e-03, ..., 5.8096612e-04,
#           4.9762969e-04, 2.4432081e-03],
#          [6.4860453e-04, 2.3094652e-05, 1.0770527e-03, ..., 3.9109751e-04,
#           8.8839093e-04, 2.2664042e-03],
#          ...,
#          [8.2893868e-04, 4.4630622e-05, 1.3142033e-03, ..., 4.9439282e-04,
#           1.3453945e-03, 1.8035672e-03],
#          [2.5280868e-04, 3.2182521e-05, 1.2285654e-03, ..., 4.6963250e-04,
#           1.4910894e-03, 2.1163751e-03],
#          [9.3217532e-04, 4.2207998e-06, 9.7380567e-04, ..., 5.5080873e-04,
#           1.0950887e-03, 2.1099763e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_1': {'time': [29.79, 58.95],
#   'cap': "nope. closet look good. door is strong. so y'all settling in? - yeah. we've been living here a year and a half, so we have. - so, uh, how are these cupboards working out for you? man, nobody in here... besides your stuff, which looks good. - thank you. - completely unrelated-- ",
#   'feature': array([[9.3217532e-04, 4.2207998e-06, 9.7380567e-04, ..., 5.5080873e-04,
#           1.0950887e-03, 2.1099763e-03],
#          [1.0097666e-03, 4.2345058e-05, 1.1991060e-03, ..., 2.5766456e-04,
#           8.5309724e-04, 1.9172578e-03],
#          [6.3452765e-04, 2.2570415e-05, 1.1995302e-03, ..., 7.1963505e-04,
#           1.1374056e-03, 1.8819612e-03],
#          ...,
#          [8.8353577e-04, 2.1527298e-05, 1.3401185e-03, ..., 4.5590571e-04,
#           8.7118678e-04, 2.2522970e-03],
#          [8.7583385e-04, 4.0444640e-05, 8.6162554e-04, ..., 8.9529663e-04,
#           4.0913781e-04, 2.5501447e-03],
#          [6.5099652e-04, 1.0902875e-05, 2.3675115e-04, ..., 5.8397208e-04,
#           2.8568585e-04, 2.5598477e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_2': {'time': [55.18, 80.14],
#   'cap': 'have y\'all seen a 4\'11" dude with a purple beard up in here? - no. no. no, no one\'s in here... probably because we lock the door. - oh, he got the body like a rat. he can just squeeze through the vents. - yeah. so you think somebody\'s hiding in my apartment? - no. i told you-- ',
#   'feature': array([[6.5099652e-04, 1.0902875e-05, 2.3675115e-04, ..., 5.8397208e-04,
#           2.8568585e-04, 2.5598477e-03],
#          [1.0831006e-03, 3.8474027e-05, 6.6470035e-04, ..., 5.9313315e-04,
#           1.3325378e-04, 2.4403129e-03],
#          [1.1653337e-03, 1.5312449e-05, 9.4715634e-04, ..., 8.8504993e-04,
#           9.0753078e-05, 2.2388489e-03],
#          ...,
#          [1.3333531e-03, 7.1179493e-05, 3.5134150e-04, ..., 1.4736977e-03,
#           1.3082501e-05, 2.4563875e-03],
#          [1.2766921e-03, 3.6593228e-05, 1.0377504e-03, ..., 6.2250893e-04,
#           5.5611570e-04, 2.2922512e-03],
#          [2.9228290e-04, 2.2502509e-05, 6.1362865e-04, ..., 5.9348671e-04,
#           1.1468909e-03, 2.3996758e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_3': {'time': [78.64, 96.76],
#   'cap': 'it\'s just a social call. i mean, why would gerald be in here, anyway? - gerald. there is a man with a purple beard named gerald in my apartment? - hell, no! why? did you see him? he about 4\'9", got a purple beard. - yeah. - hey, baby-- - [screams maniacally] ',
#   'feature': array([[2.9228290e-04, 2.2502509e-05, 6.1362865e-04, ..., 5.9348671e-04,
#           1.1468909e-03, 2.3996758e-03],
#          [3.7182734e-04, 3.1215382e-05, 8.5037050e-04, ..., 9.4023452e-04,
#           4.2710942e-04, 2.1686065e-03],
#          [7.0794160e-04, 2.5241552e-06, 9.9122839e-04, ..., 1.1615389e-03,
#           1.2456131e-04, 2.4586255e-03],
#          [3.0624814e-04, 5.4144395e-05, 1.3454701e-03, ..., 6.4527162e-04,
#           5.6753075e-04, 2.1277652e-03],
#          [5.2895013e-04, 1.8504845e-05, 5.2716833e-04, ..., 3.0708316e-04,
#           8.6750800e-04, 2.4055084e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_4': {'time': [95.66, 120.42],
#   'cap': '- [screams] - ugh! this is--agh! [grunts] oh. [laughs] hey, baby girl. you ain\'t gerald. [snickers] oh, by the by, have you seen a 4\'5" purple beard? - baby... - devon, what\'s going on? - okay, you know, i\'m gonna level with all y\'all. ',
#   'feature': array([[4.6413511e-04, 4.1983010e-05, 1.1822288e-03, ..., 3.6938768e-04,
#           2.2756838e-04, 2.2896091e-03],
#          [1.0109170e-03, 3.1257070e-05, 8.2397874e-04, ..., 2.3224019e-04,
#           1.7802919e-03, 1.9534384e-03],
#          [6.9422420e-04, 3.1459556e-05, 5.4198236e-04, ..., 5.6151429e-04,
#           5.7148561e-04, 2.3942119e-03],
#          ...,
#          [1.1079333e-03, 1.4147318e-05, 8.3058828e-04, ..., 2.2085081e-04,
#           1.5671023e-03, 2.3090448e-03],
#          [1.6598456e-04, 9.3523988e-05, 6.8717590e-04, ..., 2.5988609e-04,
#           1.2031560e-03, 2.4154538e-03],
#          [2.7054932e-04, 1.6880245e-04, 7.0626638e-04, ..., 3.1113304e-04,
#           1.9248908e-04, 2.5284004e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_5': {'time': [116.88, 140.37],
#   'cap': 'there is a 4\'3" [bleep] with a purple beard named gerald somewhere in this building. - why does he keep getting smaller every time you mention him? - seriously? \'cause i didn\'t want to alarm y\'all. he is disturbingly small, really. he a good guy. he smoke rock, though. i mean, he\'ll do anything to get money for crack. ',
#   'feature': array([[2.7054932e-04, 1.6880245e-04, 7.0626638e-04, ..., 3.1113304e-04,
#           1.9248908e-04, 2.5284004e-03],
#          [3.6384072e-04, 6.1205401e-06, 7.1282941e-04, ..., 4.6149653e-04,
#           4.7717954e-04, 2.2461845e-03],
#          [7.1615184e-04, 6.2872182e-06, 1.0019662e-03, ..., 2.0821800e-04,
#           1.3253780e-03, 1.7059594e-03],
#          [4.2693224e-04, 3.1637619e-06, 1.2789972e-03, ..., 4.1889949e-04,
#           1.6218863e-03, 2.0799506e-03],
#          [1.1271180e-03, 0.0000000e+00, 7.7953906e-04, ..., 3.5608438e-04,
#           5.5389863e-04, 2.2136560e-03],
#          [6.2812347e-04, 7.1326890e-06, 4.8976921e-04, ..., 1.4327471e-04,
#           6.4794952e-04, 2.3675824e-03]], dtype=float32)},
#  '_aa8ylQ7-mQ_6': {'time': [138.87, 165.89],
#   'cap': "anything. - okay. - i mean anything. - i get it. - he will murder you. - well, we certainly hope you find him. - oh, i'm gonna find him. don't worry about that, 'cause i'm gonna look low, and then i'm gonna look high. ",
#   'feature': array([[9.0304512e-04, 7.2963463e-05, 9.6165342e-04, ..., 2.2645944e-04,
#           1.1583667e-03, 2.5615441e-03],
#          [9.0698909e-04, 0.0000000e+00, 7.2008697e-04, ..., 7.5815100e-05,
#           1.3151325e-04, 2.5152555e-03],
#          [9.1895845e-04, 4.9374908e-06, 8.0672395e-04, ..., 2.1884246e-04,
#           9.3782664e-04, 2.2097179e-03],
#          ...,
#          [1.2708276e-03, 3.7877995e-05, 5.8504450e-04, ..., 3.5535678e-04,
#           7.1428611e-04, 2.0232620e-03],
#          [7.0699654e-04, 8.2199640e-06, 7.4518216e-04, ..., 2.2309941e-04,
#           9.3070854e-04, 2.5229359e-03],
#          [1.0173374e-03, 0.0000000e+00, 4.3325222e-04, ..., 3.7932865e-04,
#           5.2668981e-04, 2.3970152e-03]], dtype=float32)},
#  ...}

# %% [markdown]
# ## Generate the total annotation file

# %%
total_ann = {}
num_feat = 0
count = 0

for num_idx in captions['id']:
    video_idx = captions['id'][num_idx]
    
    # If videos are not available in S3D Hub
    if video_idx not in s3d_feat:
        break
        
    # Extract captions, time and s3d features for this video
    cap_list = captions['raw_caption'][num_idx]
    s_list = captions['start'][num_idx]
    e_list = captions['end'][num_idx]
    total_time = e_list[-1]
    total_feat = s3d_feat[video_idx].shape[0]
    
    # Iterate the video clips
    clip_idx = 0
    length = len(cap_list)
    interval = 10
    
    for i in range(0, length, interval):
        clip_ann = {}
        start = s_list[i]
        end = e_list[min(i+interval, len(e_list)-1)]
        
        clip_ann['time'] = [start, end]
        clip_ann['cap'] = list_to_sent(cap_list[i: i+interval])
        clip_ann['feature'] = s3d_feat[video_idx][round((start/total_time)*total_feat):
                                                  round((end/total_time)*total_feat)]
        _ = video_idx + '_' + str(clip_idx)
        total_ann[_] = clip_ann
        clip_idx += 1
        num_feat += round((end/total_time)*total_feat)- round((start/total_time)*total_feat)
        count += 1

# %%
# Save the annotation file
pickle.dump(total_ann, open('1600captioning.pkl', 'wb'))

# %%
len(total_ann.keys())
# Out:
# 4249

# %% [markdown]
# ## Get the word_to_id and id_to_word

# %%
word_to_ix = {}
word_to_ix["<sep>"] = 4
word_to_ix["<eos>"] = 3
word_to_ix["<sos>"] = 2
word_to_ix["<UNK>"] = 1
word_to_ix["<PAD>"] = 0

idx = 5
for num_idx in captions['id']:
    video_idx = captions['id'][num_idx]
    
    # If videos are not available in S3D Hub
    if video_idx not in s3d_feat:
        break
        
    # Extract captions, time and s3d features for this video
    cap_list = captions['raw_caption'][num_idx]
    for sentence in cap_list:
        words = sentence.lower().split(' ')
        for word in words:
            if word not in word_to_ix:
                word_to_ix[word] = idx
                idx += 1
                
ix_to_word = {}
for word in word_to_ix:
    ix = word_to_ix[word]
    ix_to_word[str(ix)] = word

# %%
vocab = {}
vocab['word_to_ix'] = word_to_ix
vocab['ix_to_word'] = ix_to_word

# Save the annotation file
pickle.dump(vocab, open('vocab.pkl', 'wb'))

# %% [markdown]
# ## Split the training and testing split

# %%
import pickle

_ = './data/1600captioning.pkl'
ann = pickle.load(open(_, 'rb'), encoding="utf-32")

# %%
import random

video_idx = list(ann.keys())
random.shuffle(video_idx)

train_idx = video_idx[0:3000]
test_idx = video_idx[3000:]

# %%
splits = {}
splits['train'] = train_idx
splits['test'] = test_idx

pickle.dump(splits, open('splits.pkl', 'wb'))

# %%
len(test_idx)
# Out:
# 2109

# %%
len(train_idx)
# Out:
# 6223

# %% [markdown]
# ## Dataloader File

# %%
splits.keys()
# Out:
# dict_keys(['train', 'test'])

# %%
'''
    Author: Zhiyuan Jacob Fang
    Dataset script to load and collate batch files.
'''
import os
import cv2
import pickle
import torch
import random
import numpy as np
from torchvision import transforms
from torch.utils.data import Dataset


class How2100MDataset(Dataset):

    # Auxiliary functions
    def get_vocab_size(self):
        return len(self.get_vocab())

    def get_vocab(self):
        return self.word_to_ix

    def get_ix_to_word(self):
        return self.ix_to_word

    def __init__(self, opt, mode='train'):
        super(How2100MDataset, self).__init__()
        self.opt = opt
        self.mode = mode

        # Load the caption annotations
        self.caption_hub = pickle.load(open(os.path.join(opt['ann_path'], opt['cap_file']), 'rb'))

        # Read the training/testing split
        self.splits = pickle.load(open(os.path.join(opt['ann_path'], opt['splits']), 'rb')) [mode]
        
        # Read the vocabulary file
        vocab = pickle.load(open(os.path.join(opt['ann_path'], opt['vocab']), 'rb')) 
            
        # Load the vocabulary dictionary
        self.word_to_ix = vocab['word_to_ix']
        self.ix_to_word = vocab['ix_to_word']

    def __getitem__(self, video_id=False):

        video_id = self.splits[video_id]

        # Load the caption and time boundaries
        data = {}
        annotation = self.caption_hub[video_id]
        time = annotation['time']
        cap = annotation['cap']
        feature = annotation['feature']

        data['video_feat'] = torch.tensor(feature)
        data['time'] = time
        data['caption'] = cap
        data['video_id'] = video_id
        data['arr_length'] = data['video_feat'].shape[0]
        return data

    def __len__(self):
        length = len(self.splits)
        return length


# batch collate function
def collate_fn(batch_lst):
    '''
    :param batch_lst: Raw instance level annotation from YC2 Dataset class.
    :return: batch annotations that include: features, captions, segments, length of features and length of videos.
    '''
    batch_lens = [_['arr_length'] for _ in batch_lst]
    max_length = max(batch_lens)
    batch_feat = torch.zeros((len(batch_lst), max_length, 512))
    captions = []
    video_ids = []

    for batch_id, batch_data in enumerate(batch_lst):
        batch_feat[batch_id][: batch_data['arr_length']] = batch_data['video_feat']
        captions.append(batch_data['caption'])
        video_ids.append(batch_data['video_id'])
    return batch_feat, captions, torch.tensor(batch_lens), video_ids

# %%
opt = {}
opt['ann_path'] = './data'
opt['cap_file'] = '1600captioning.pkl'
opt['splits'] = 'splits.pkl'
opt['vocab'] = 'vocab.pkl'

from torch.utils.data import DataLoader
dataset = How2100MDataset(opt, mode='train')
dataloader = DataLoader(dataset, batch_size=1, shuffle=True, collate_fn=collate_fn)

# %%
l = []
for batch_feat, captions, video_lens, video_ids in dataloader:
    l.append(len(captions[0].split(' ')))

# %%
max(l)
# Out:
# 176

# %%
captions
# Out:
# ["motor buying it's a shame it will be quite easy to move the bike or worse knock it over five kinds of aggressive spider-man to the rescue of all fellow motorist and ensuring that everyone abides by the universal laws of the road like using one parking five instead of two and by using only one spot being a huge help to all of humanity thanks spider-man 4 it's the celebration "]

# %% [markdown]
# ## Statistics about the current captioniong task

# %%
#C, M, R, B: 0.003142048088866361 0.05902108271759048 0.12412222552064847 [0.12006724945117442, 0.03762453494350962, 0.013472772457743728, 0.005297708520132779]
print('Cider: {:.6f}, Meteor: {:.6f}, Rouge: {:.6f}, BLEU: {:.6f}, {:.6f}, {:.6f}, {:.6f}'
      .format(0.0044643, 0.05524047, 0.12112913, 0.1187265, 0.0325400,0.0107119754, 0.0042136144795))
# Out:
# Cider: 0.003142, Meteor: 0.059021, Rouge: 0.124122, BLEU: 0.120067, 0.037625, 0.013473, 0.005298

# %%
import pandas as pd
data = [[176, 15457, 9], [28, 2000, 30]]
pd.DataFrame(data, columns=["Max Len. of Sent.", "Size of Vocab", "Avg. Len. of Feat."])
# Out:
#    Max Len. of Sent.  Size of Vocab  Avg. Len. of Feat.
# 0                176          15457                   9
# 1                 28           2000                  30
